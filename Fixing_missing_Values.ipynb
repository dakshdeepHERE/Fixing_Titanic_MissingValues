# %%
import pandas as pd

# %%
life_expentancy_df = pd.read_csv('Life_Expectancy_at_Birth.csv')

# %%
life_expentancy.head()
# Out:
#   ISO3               Country Continent           Hemisphere
# 0  AFG           Afghanistan      Asia  Northern Hemisphere  \
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 3  AND               Andorra    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)
# 0                      Low                      SA            180.0  \
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 3                Very High                     NaN             40.0
# 4                Very High                      AS             26.0
#
#    Life Expectancy at Birth (1990)  Life Expectancy at Birth (1991)
# 0                          45.9672                          46.6631  \
# ...

# %%
Asian_country= life_expentancy_df[(life_expentancy_df['Continent'] == 'Asia') & (life_expentancy_df['HDI Rank (2021)'] >= 150)]

# %%
selected_columns = Asian_country[['Hemisphere', 'Human Development Groups', 'Life Expectancy at Birth (2021)','Life Expectancy at Birth (2020)']]

# %%
selected_columns
# Out:
#               Hemisphere Human Development Groups
# 0    Northern Hemisphere                      Low  \
# 135  Northern Hemisphere                      Low
# 168  Northern Hemisphere                   Medium
# 191  Northern Hemisphere                      Low
#
#      Life Expectancy at Birth (2021)  Life Expectancy at Birth (2020)
# 0                            61.9824                          62.5751
# 135                          66.0979                          66.2695
# 168                          72.0627                          72.1399
# 191                          63.7534                          64.6501

# %%
life_expentancy_df.isnull()
# Out:
#       ISO3  Country  Continent  Hemisphere  Human Development Groups
# 0    False    False      False       False                     False  \
# 1    False    False      False       False                     False
# 2    False    False      False       False                     False
# 3    False    False      False       False                     False
# 4    False    False      False       False                     False
# ..     ...      ...        ...         ...                       ...
# 190  False    False      False       False                     False
# 191  False    False      False       False                     False
# 192  False    False      False       False                     False
# 193  False    False      False       False                     False
# 194  False    False      False       False                     False
#
#      UNDP Developing Regions  HDI Rank (2021)
# 0                      False            False  \
# ...

# %%
life_expentancy_df.isnull().sum()
# Out:
# ISO3                                0
# Country                             0
# Continent                           0
# Hemisphere                          0
# Human Development Groups            4
# UNDP Developing Regions            44
# HDI Rank (2021)                     4
# Life Expectancy at Birth (1990)     0
# Life Expectancy at Birth (1991)     0
# Life Expectancy at Birth (1992)     0
# Life Expectancy at Birth (1993)     0
# Life Expectancy at Birth (1994)     0
# Life Expectancy at Birth (1995)     0
# Life Expectancy at Birth (1996)     0
# Life Expectancy at Birth (1997)     0
# Life Expectancy at Birth (1998)     0
# Life Expectancy at Birth (1999)     0
# Life Expectancy at Birth (2000)     0
# Life Expectancy at Birth (2001)     0
# Life Expectancy at Birth (2002)     0
# Life Expectancy at Birth (2003)     0
# Life Expectancy at Birth (2004)     0
# Life Expectancy at Birth (2005)     0
# Life Expectancy at Birth (2006)     0
# Life Expectancy at Birth (2007)     0
# ...

# %%
    ## Developing_region_mean = life_expentancy_df["UNDP Developing Regions"].mean().unique()

    life_expentancy_df['UNDP Developing Regions'].unique()
# Out:
# array(['SA', 'SSA', 'ECA', nan, 'AS', 'LAC', 'EAP'], dtype=object)

# %%
UDP_dev = life_expentancy_df['UNDP Developing Regions'].mode()[0]

# %%
print(UDP_dev)
# Out:
# SSA

# %%
life_expentancy_df['UNDP Developing Regions'].fillna(UDP_dev,inplace=True)

# %%
print(life_expentancy_df['UNDP Developing Regions'])
# Out:
# 0       SA
# 1      SSA
# 2      ECA
# 3      SSA
# 4       AS
#       ...
# 190    EAP
# 191     AS
# 192    SSA
# 193    SSA
# 194    SSA
# Name: UNDP Developing Regions, Length: 195, dtype: object

# %%
life_expentancy_df.isnull()
# Out:
#       ISO3  Country  Continent  Hemisphere  Human Development Groups
# 0    False    False      False       False                     False  \
# 1    False    False      False       False                     False
# 2    False    False      False       False                     False
# 3    False    False      False       False                     False
# 4    False    False      False       False                     False
# ..     ...      ...        ...         ...                       ...
# 190  False    False      False       False                     False
# 191  False    False      False       False                     False
# 192  False    False      False       False                     False
# 193  False    False      False       False                     False
# 194  False    False      False       False                     False
#
#      UNDP Developing Regions  HDI Rank (2021)
# 0                      False            False  \
# ...

# %%
life_expentancy_df.isnull().sum()
# Out:
# ISO3                               0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Human Development Groups           4
# UNDP Developing Regions            0
# HDI Rank (2021)                    4
# Life Expectancy at Birth (1990)    0
# Life Expectancy at Birth (1991)    0
# Life Expectancy at Birth (1992)    0
# Life Expectancy at Birth (1993)    0
# Life Expectancy at Birth (1994)    0
# Life Expectancy at Birth (1995)    0
# Life Expectancy at Birth (1996)    0
# Life Expectancy at Birth (1997)    0
# Life Expectancy at Birth (1998)    0
# Life Expectancy at Birth (1999)    0
# Life Expectancy at Birth (2000)    0
# Life Expectancy at Birth (2001)    0
# Life Expectancy at Birth (2002)    0
# Life Expectancy at Birth (2003)    0
# Life Expectancy at Birth (2004)    0
# Life Expectancy at Birth (2005)    0
# Life Expectancy at Birth (2006)    0
# Life Expectancy at Birth (2007)    0
# ...

# %%
life_expentancy_df = life_expentancy_df.dropna(subset=['HDI Rank (2021)'])

# %%
life_expentancy_df.isnull().sum()
# Out:
# ISO3                               0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Human Development Groups           0
# UNDP Developing Regions            0
# HDI Rank (2021)                    0
# Life Expectancy at Birth (1990)    0
# Life Expectancy at Birth (1991)    0
# Life Expectancy at Birth (1992)    0
# Life Expectancy at Birth (1993)    0
# Life Expectancy at Birth (1994)    0
# Life Expectancy at Birth (1995)    0
# Life Expectancy at Birth (1996)    0
# Life Expectancy at Birth (1997)    0
# Life Expectancy at Birth (1998)    0
# Life Expectancy at Birth (1999)    0
# Life Expectancy at Birth (2000)    0
# Life Expectancy at Birth (2001)    0
# Life Expectancy at Birth (2002)    0
# Life Expectancy at Birth (2003)    0
# Life Expectancy at Birth (2004)    0
# Life Expectancy at Birth (2005)    0
# Life Expectancy at Birth (2006)    0
# Life Expectancy at Birth (2007)    0
# ...

# %%
#. No missing values in the end in any columns :)
